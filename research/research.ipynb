# %%
info = {
    'name': 'ali khan', 
    'city':'karachi'
}

# %%
# info.get('name')
# info['name']
info.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 # info.get('name')
#       2 # info['name']
# ----> 3 info.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox
new_info = ConfigBox(info)

# %%
new_info.name
# Out:
# 'ali khan'

# %%
from ensure import ensure_annotations
def product(a, b):
    return a*b

# %%
product(1,2)
# Out:
# 2

# %%
product(2,'2')
# Out:
# '22'

# %%
@ensure_annotations
def f(x: int, y: float) -> float:
    return x+y

# %%
f(1,1.1)
# Out:
# 2.1
